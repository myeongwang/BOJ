# %% [markdown]
# ## 2020.09.02 (wed)
#
# ## coding restarting day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## fail

# %%
nums= list(map(int , input().split()))
T=0

""" 
N= int(input())
M= int(input())
K= int(input())
T=0 """

if nums[0]//2 >= nums[1]:
    T= nums[1]
    
    if nums[2]>3:
        
    
    elif nums[2]<=3:
        T-1
        
else:
    
    if nums[2]>3:
        
    
    elif nums[2]<=3:
# Out:
#   File "<ipython-input-22-ea5fcc6335c5>", line 16
#     elif nums[2]<=3:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# ## success

# %%
woman, man, k = map(int, input().split()) 
team = 0 
while woman >=2 and man >=1 and woman+man >= k+3 : 
    woman -= 2 
    man -= 1 
    team += 1 
print(team)
# Out:
# 6 3 2
# 2

# %% [markdown]
# # Q. 10610

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = input()

s = 0
if '0' not in N: # so do not transforming type 'int'
    print(-1)
else:
    for i in N:
        s+=int(i)
    if s%3 != 0:
        print(-1)
    else:
        print(''.join(sorted(N,reverse=True)))
# Out:
# 102
# 210
